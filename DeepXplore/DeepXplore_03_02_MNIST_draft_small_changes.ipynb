# %% [markdown]
# <a href="https://colab.research.google.com/github/isshii/de4test/blob/test_ozawa/DeepXplore/DeepXplore_03_02_MNIST_draft_small_changes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 共通で使うパスなどの定義
# 共通の変数設定
# 共通フォルダパス
data_dir = "/content/gdrive/My Drive/ColabNotebooks/test4ai/data"
#data_imagenet = "/content/gdrive/My Drive/ColabNotebooks/test4ai/data/ImageNet"
data_mnist = "/content/gdrive/My Drive/ColabNotebooks/test4ai/data/MNIST"
#data_imagenet_seeds = "/content/gdrive/My Drive/ColabNotebooks/test4ai/data/ImageNet/seeds"
model_dir = "/content/gdrive/My Drive/ColabNotebooks/test4ai/model"
output_dir = "/content/gdrive/My Drive/ColabNotebooks/test4ai/output"
tmp_dir = "/content/gdrive/My Drive/ColabNotebooks/test4ai/tmp"

# %%
# Goggle Drive つなぐ
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# outputフォルダ内容物のクリーンアップ削除
# !rm "$output_dir"/*

# %%
import sys
sys.path.append('/content/gdrive/My Drive/ColabNotebooks/test4ai/model/MNIST')

class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %%
import argparse

# %tensorflow_version 1.x
from keras.datasets import mnist
from keras.layers import Input
import imageio

from __future__ import print_function

from keras.datasets import mnist
from keras.layers import Convolution2D, MaxPooling2D, Input, Dense, Activation, Flatten
from keras.models import Model
from keras.utils import to_categorical
import os
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6811647981944052519, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 11673532583214703921
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 10369054008250152956
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15956161332
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10609314168119972377
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
#@title デフォルトのタイトル テキスト
# DeepXplore のパラメータ設定部
# read the parameter
# argument parsing
parser = argparse.ArgumentParser(description='Main function for difference-inducing input generation in MNIST dataset')
parser.add_argument('transformation', help="realistic transformation type", choices=['light', 'occl', 'blackout'])
parser.add_argument('weight_diff', help="weight hyperparm to control differential behavior", type=float)
parser.add_argument('weight_nc', help="weight hyperparm to control neuron coverage", type=float)
parser.add_argument('step', help="step size of gradient descent", type=float)
parser.add_argument('seeds', help="number of seeds of input", type=int)
parser.add_argument('grad_iterations', help="number of iterations of gradient descent", type=int)
parser.add_argument('threshold', help="threshold for determining neuron activated", type=float)
parser.add_argument('-t', '--target_model', help="target model that we want it predicts differently",
                    choices=[0, 1, 2], default=0, type=int)
parser.add_argument('-sp', '--start_point', help="occlusion upper left corner coordinate", default=(0, 0), type=tuple)
parser.add_argument('-occl_size', '--occlusion_size', help="occlusion size", default=(10, 10), type=tuple)
# Out:
# _StoreAction(option_strings=['-occl_size', '--occlusion_size'], dest='occlusion_size', nargs=None, const=None, default=(10, 10), type=<class 'tuple'>, choices=None, help='occlusion size', metavar=None)

# %%
#@title ノイズのタイプ light / occl / blackout
#@body {light,occl,blackout} weight_diff weight_nc step seeds
#                   grad_iterations threshold
noise_type = "light" #@param ["light", "occl", "blackout"]
weight_diff = "0.1" #@param {type:"string"}
weight_nc = "0.1" #@param {type:"string"}
step = "20" #@param {type:"string"}　#50だとほぼ白飛び
seeds = "200" #@param {type:"string"}
grad_iterations = "10" #@param {type:"string"}
threshold = "0.1" #@param {type:"string"}

# %%
args = parser.parse_args([noise_type, weight_diff, weight_nc, step, seeds, grad_iterations, threshold])

# %%
import random
from collections import defaultdict

import numpy as np
from keras import backend as K
from keras.models import Model


# util function to convert a tensor into a valid image
def deprocess_image(x):
    x *= 255
    x = np.clip(x, 0, 255).astype('uint8')
    return x.reshape(x.shape[1], x.shape[2])  # original shape (1,img_rows, img_cols,1)


def normalize(x):
    # utility function to normalize a tensor by its L2 norm
    return x / (K.sqrt(K.mean(K.square(x))) + 1e-5)


def constraint_occl(gradients, start_point, rect_shape):
    new_grads = np.zeros_like(gradients)
    new_grads[:, start_point[0]:start_point[0] + rect_shape[0],
    start_point[1]:start_point[1] + rect_shape[1]] = gradients[:, start_point[0]:start_point[0] + rect_shape[0],
                                                     start_point[1]:start_point[1] + rect_shape[1]]
    return new_grads


def constraint_light(gradients):
    new_grads = np.ones_like(gradients)
    grad_mean = np.mean(gradients)
    return grad_mean * new_grads


def constraint_black(gradients, rect_shape=(6, 6)):
    start_point = (
        random.randint(0, gradients.shape[1] - rect_shape[0]), random.randint(0, gradients.shape[2] - rect_shape[1]))
    new_grads = np.zeros_like(gradients)
    patch = gradients[:, start_point[0]:start_point[0] + rect_shape[0], start_point[1]:start_point[1] + rect_shape[1]]
    if np.mean(patch) < 0:
        new_grads[:, start_point[0]:start_point[0] + rect_shape[0],
        start_point[1]:start_point[1] + rect_shape[1]] = -np.ones_like(patch)
    return new_grads


def init_coverage_tables(model1, model2, model3):
    model_layer_dict1 = defaultdict(bool)
    model_layer_dict2 = defaultdict(bool)
    model_layer_dict3 = defaultdict(bool)
    init_dict(model1, model_layer_dict1)
    init_dict(model2, model_layer_dict2)
    init_dict(model3, model_layer_dict3)
    return model_layer_dict1, model_layer_dict2, model_layer_dict3


def init_dict(model, model_layer_dict):
    for layer in model.layers:
        if 'flatten' in layer.name or 'input' in layer.name:
            continue
        for index in range(layer.output_shape[-1]):
            model_layer_dict[(layer.name, index)] = False


def neuron_to_cover(model_layer_dict):
    not_covered = [(layer_name, index) for (layer_name, index), v in model_layer_dict.items() if not v]
    if not_covered:
        layer_name, index = random.choice(not_covered)
    else:
        layer_name, index = random.choice(model_layer_dict.keys())
    return layer_name, index


def neuron_covered(model_layer_dict):
    covered_neurons = len([v for v in model_layer_dict.values() if v])
    total_neurons = len(model_layer_dict)
    return covered_neurons, total_neurons, covered_neurons / float(total_neurons)


def update_coverage(input_data, model, model_layer_dict, threshold=0):
    layer_names = [layer.name for layer in model.layers if
                   'flatten' not in layer.name and 'input' not in layer.name]

    intermediate_layer_model = Model(inputs=model.input,
                                     outputs=[model.get_layer(layer_name).output for layer_name in layer_names])
    intermediate_layer_outputs = intermediate_layer_model.predict(input_data)

    for i, intermediate_layer_output in enumerate(intermediate_layer_outputs):
        scaled = scale(intermediate_layer_output[0])
        for num_neuron in range(scaled.shape[-1]):
            if np.mean(scaled[..., num_neuron]) > threshold and not model_layer_dict[(layer_names[i], num_neuron)]:
                model_layer_dict[(layer_names[i], num_neuron)] = True


def full_coverage(model_layer_dict):
    if False in model_layer_dict.values():
        return False
    return True


def scale(intermediate_layer_output, rmax=1, rmin=0):
    X_std = (intermediate_layer_output - intermediate_layer_output.min()) / (
        intermediate_layer_output.max() - intermediate_layer_output.min())
    X_scaled = X_std * (rmax - rmin) + rmin
    return X_scaled


def fired(model, layer_name, index, input_data, threshold=0):
    intermediate_layer_model = Model(inputs=model.input, outputs=model.get_layer(layer_name).output)
    intermediate_layer_output = intermediate_layer_model.predict(input_data)[0]
    scaled = scale(intermediate_layer_output)
    if np.mean(scaled[..., index]) > threshold:
        return True
    return False


def diverged(predictions1, predictions2, predictions3, target):
    #     if predictions2 == predictions3 == target and predictions1 != target:
    if not predictions1 == predictions2 == predictions3:
        return True
    return False


#add
def list_pictures(directory, ext='jpg|jpeg|bmp|png|ppm'):
    return [os.path.join(root, f)
            for root, _, files in os.walk(directory) for f in files
            if re.match(r'([\w]+\.(?:' + ext + '))', f.lower())]

# %%
# input image dimensions
img_rows, img_cols = 28, 28
# the data, shuffled and split between train and test sets
(_, _), (x_test, _) = mnist.load_data()

x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
input_shape = (img_rows, img_cols, 1)

x_test = x_test.astype('float32')
x_test /= 255

# define input tensor as a placeholder
input_tensor = Input(shape=input_shape)
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
'''
LeNet-1
'''
def Model1(input_tensor=None, train=False):
    nb_classes = 10
    # convolution kernel size
    kernel_size = (5, 5)

    if train:
        batch_size = 256
        nb_epoch = 10

        # input image dimensions
        img_rows, img_cols = 28, 28

        # the data, shuffled and split between train and test sets
        (x_train, y_train), (x_test, y_test) = mnist.load_data()

        print(x_train.shape)
        x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
        x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
        input_shape = (img_rows, img_cols, 1)

        x_train = x_train.astype('float32')
        x_test = x_test.astype('float32')
        x_train /= 255
        x_test /= 255

        # convert class vectors to binary class matrices
        y_train = to_categorical(y_train, nb_classes)
        y_test = to_categorical(y_test, nb_classes)

        input_tensor = Input(shape=input_shape)
    elif input_tensor is None:
        print(bcolors.FAIL + 'you have to proved input_tensor when testing')
        exit()

    # block1
    x = Convolution2D(4, kernel_size, activation='relu', padding='same', name='block1_conv1')(input_tensor)
    x = MaxPooling2D(pool_size=(2, 2), name='block1_pool1')(x)

    # block2
    x = Convolution2D(12, kernel_size, activation='relu', padding='same', name='block2_conv1')(x)
    x = MaxPooling2D(pool_size=(2, 2), name='block2_pool1')(x)

    x = Flatten(name='flatten')(x)
    x = Dense(nb_classes, name='before_softmax')(x)
    x = Activation('softmax', name='predictions')(x)

    model = Model(input_tensor, x)

    if train:
        # compiling
        model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

        # trainig
        model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=batch_size, epochs=nb_epoch, verbose=1)
        # save model
#        model.save_weights('./Model1.h5')
        model.save_weights('/content/gdrive/My Drive/ColabNotebooks/test4ai/model/MNIST/Model1.h5')
        score = model.evaluate(x_test, y_test, verbose=0)
        print('\n')
        print('Overall Test score:', score[0])
        print('Overall Test accuracy:', score[1])
    else:
#        model.load_weights('./Model1.h5')
        model.load_weights('/content/gdrive/My Drive/ColabNotebooks/test4ai/model/MNIST/Model1.h5')
        print(bcolors.OKBLUE + 'Model1 loaded' + bcolors.ENDC)

    return model


if __name__ == '__main__':
    Model1(train=True)
# Out:
# (60000, 28, 28)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.4670 - acc: 0.8562 - val_loss: 0.1524 - val_acc: 0.9544
# Epoch 2/10
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.1256 - acc: 0.9627 - val_loss: 0.0947 - val_acc: 0.9710
# Epoch 3/10
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0959 - acc: 0.9711 - val_loss: 0.0789 - val_acc: 0.9746
# Epoch 4/10
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0807 - acc: 0.9750 - val_loss: 0.0756 - val_acc: 0.9758
# Epoch 5/10
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0711 - acc: 0.9775 - val_loss: 0.0595 - val_acc: 0.9803
# Epoch 6/10
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0635 - acc: 0.9805 - val_loss: 0.0655 - val_acc: 0.9783
# Epoch 7/10
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0583 - acc: 0.9816 - val_loss: 0.0590 - val_acc: 0.9804
# Epoch 8/10
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0539 - acc: 0.9830 - val_loss: 0.0601 - val_acc: 0.9805
# Epoch 9/10
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.0505 - acc: 0.9844 - val_loss: 0.0454 - val_acc: 0.9845
# Epoch 10/10
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0472 - acc: 0.9851 - val_loss: 0.0429 - val_acc: 0.9859
#
#
# Overall Test score: 0.04293612037352286
# Overall Test accuracy: 0.9859

# %%
'''
LeNet-4
'''
def Model2(input_tensor=None, train=False):
    nb_classes = 10
    # convolution kernel size
    kernel_size = (5, 5)

    if train:
        batch_size = 256
        nb_epoch = 10

        # input image dimensions
        img_rows, img_cols = 28, 28

        # the data, shuffled and split between train and test sets
        (x_train, y_train), (x_test, y_test) = mnist.load_data()

        x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
        x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
        input_shape = (img_rows, img_cols, 1)

        x_train = x_train.astype('float32')
        x_test = x_test.astype('float32')
        x_train /= 255
        x_test /= 255

        # convert class vectors to binary class matrices
        y_train = to_categorical(y_train, nb_classes)
        y_test = to_categorical(y_test, nb_classes)

        input_tensor = Input(shape=input_shape)
    elif input_tensor is None:
        print(bcolors.FAIL + 'you have to proved input_tensor when testing')
        exit()

    # block1
    x = Convolution2D(6, kernel_size, activation='relu', padding='same', name='block1_conv1')(input_tensor)
    x = MaxPooling2D(pool_size=(2, 2), name='block1_pool1')(x)

    # block2
    x = Convolution2D(16, kernel_size, activation='relu', padding='same', name='block2_conv1')(x)
    x = MaxPooling2D(pool_size=(2, 2), name='block2_pool1')(x)

    x = Flatten(name='flatten')(x)
    x = Dense(84, activation='relu', name='fc1')(x)
    x = Dense(nb_classes, name='before_softmax')(x)
    x = Activation('softmax', name='predictions')(x)

    model = Model(input_tensor, x)

    if train:
        # compiling
        model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

        # trainig
        model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=batch_size, epochs=nb_epoch, verbose=1)
        # save model
        model.save_weights('./Model2.h5')
        score = model.evaluate(x_test, y_test, verbose=0)
        print('\n')
        print('Overall Test score:', score[0])
        print('Overall Test accuracy:', score[1])
    else:
        model.load_weights('./Model2.h5')
        print(bcolors.OKBLUE + 'Model2 loaded' + bcolors.ENDC)

    return model


if __name__ == '__main__':
    Model2(train=True)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.3724 - acc: 0.8848 - val_loss: 0.1420 - val_acc: 0.9538
# Epoch 2/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.0948 - acc: 0.9712 - val_loss: 0.0692 - val_acc: 0.9778
# Epoch 3/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0667 - acc: 0.9794 - val_loss: 0.0846 - val_acc: 0.9709
# Epoch 4/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0513 - acc: 0.9843 - val_loss: 0.0463 - val_acc: 0.9851
# Epoch 5/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0421 - acc: 0.9871 - val_loss: 0.0443 - val_acc: 0.9852
# Epoch 6/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.0356 - acc: 0.9889 - val_loss: 0.0387 - val_acc: 0.9880
# Epoch 7/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0309 - acc: 0.9900 - val_loss: 0.0470 - val_acc: 0.9844
# Epoch 8/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.0260 - acc: 0.9918 - val_loss: 0.0352 - val_acc: 0.9893
# Epoch 9/10
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.0233 - acc: 0.9925 - val_loss: 0.0334 - val_acc: 0.9884
# Epoch 10/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0207 - acc: 0.9933 - val_loss: 0.0263 - val_acc: 0.9905
#
#
# Overall Test score: 0.02633722493705136
# Overall Test accuracy: 0.9905

# %%
'''
LeNet-5
'''
def Model3(input_tensor=None, train=False):
    nb_classes = 10
    # convolution kernel size
    kernel_size = (5, 5)

    if train:
        batch_size = 256
        nb_epoch = 10

        # input image dimensions
        img_rows, img_cols = 28, 28

        # the data, shuffled and split between train and test sets
        (x_train, y_train), (x_test, y_test) = mnist.load_data()

        x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
        x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
        input_shape = (img_rows, img_cols, 1)

        x_train = x_train.astype('float32')
        x_test = x_test.astype('float32')
        x_train /= 255
        x_test /= 255

        # convert class vectors to binary class matrices
        y_train = to_categorical(y_train, nb_classes)
        y_test = to_categorical(y_test, nb_classes)

        input_tensor = Input(shape=input_shape)
    elif input_tensor is None:
        print(bcolors.FAIL + 'you have to proved input_tensor when testing')
        exit()

    # block1
    x = Convolution2D(6, kernel_size, activation='relu', padding='same', name='block1_conv1')(input_tensor)
    x = MaxPooling2D(pool_size=(2, 2), name='block1_pool1')(x)

    # block2
    x = Convolution2D(16, kernel_size, activation='relu', padding='same', name='block2_conv1')(x)
    x = MaxPooling2D(pool_size=(2, 2), name='block2_pool1')(x)

    x = Flatten(name='flatten')(x)
    x = Dense(120, activation='relu', name='fc1')(x)
    x = Dense(84, activation='relu', name='fc2')(x)
    x = Dense(nb_classes, name='before_softmax')(x)
    x = Activation('softmax', name='predictions')(x)

    model = Model(input_tensor, x)

    if train:
        # compiling
        model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

        # trainig
        model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=batch_size, epochs=nb_epoch, verbose=1)
        # save model
        model.save_weights('./Model3.h5')
        score = model.evaluate(x_test, y_test, verbose=0)
        print('\n')
        print('Overall Test score:', score[0])
        print('Overall Test accuracy:', score[1])
    else:
        model.load_weights('./Model3.h5')
        print(bcolors.OKBLUE + 'Model3 loaded' + bcolors.ENDC)

    return model


if __name__ == '__main__':
    Model3(train=True)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.4327 - acc: 0.8627 - val_loss: 0.1450 - val_acc: 0.9532
# Epoch 2/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0891 - acc: 0.9716 - val_loss: 0.0719 - val_acc: 0.9757
# Epoch 3/10
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.0591 - acc: 0.9815 - val_loss: 0.0429 - val_acc: 0.9858
# Epoch 4/10
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.0446 - acc: 0.9860 - val_loss: 0.0441 - val_acc: 0.9841
# Epoch 5/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0373 - acc: 0.9881 - val_loss: 0.0456 - val_acc: 0.9849
# Epoch 6/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0313 - acc: 0.9904 - val_loss: 0.0341 - val_acc: 0.9891
# Epoch 7/10
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.0262 - acc: 0.9920 - val_loss: 0.0349 - val_acc: 0.9885
# Epoch 8/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0220 - acc: 0.9932 - val_loss: 0.0345 - val_acc: 0.9889
# Epoch 9/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.0191 - acc: 0.9939 - val_loss: 0.0467 - val_acc: 0.9851
# Epoch 10/10
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.0162 - acc: 0.9947 - val_loss: 0.0332 - val_acc: 0.9892
#
#
# Overall Test score: 0.033169857657555986
# Overall Test accuracy: 0.9892

# %%
model1 = Model1(input_tensor=input_tensor)
model2 = Model2(input_tensor=input_tensor)
model3 = Model3(input_tensor=input_tensor)
model_layer_dict1, model_layer_dict2, model_layer_dict3 = init_coverage_tables(model1, model2, model3)
# Out:
# Model1 loaded
# Model2 loaded
# Model3 loaded

# %%
# start gen inputs
# img_paths = list_pictures(data_imagenet_seeds)

# %%
# %%time

count_already = 0
count_found = 0
count_not_found = 0
for _ in range(args.seeds):
    gen_img = np.expand_dims(random.choice(x_test), axis=0)
    orig_img = gen_img.copy()
    # first check if input already induces differences
    label1, label2, label3 = np.argmax(model1.predict(gen_img)[0]), np.argmax(model2.predict(gen_img)[0]), np.argmax(model3.predict(gen_img)[0])

    if not label1 == label2 == label3:
        count_already += 1
        print(bcolors.OKGREEN + '{}/{}. input already causes different outputs ({},{},{}) at{}/{}: '.format(_, args.seeds, label1, label2, label3, count_already, count_already + count_found + count_not_found) + bcolors.ENDC)
#        print(bcolors.OKBLUE + '{}/{}. input already causes different outputs: {}, {}, {}'.format(_, args.seeds, label1, label2, label3) + bcolors.ENDC)
        

        update_coverage(gen_img, model1, model_layer_dict1, args.threshold)
        update_coverage(gen_img, model2, model_layer_dict2, args.threshold)
        update_coverage(gen_img, model3, model_layer_dict3, args.threshold)

        print(bcolors.OKGREEN + '     covered neurons percentage %d neurons %.3f, %d neurons %.3f, %d neurons %.3f'
              % (len(model_layer_dict1), neuron_covered(model_layer_dict1)[2], len(model_layer_dict2),
                 neuron_covered(model_layer_dict2)[2], len(model_layer_dict3),
                 neuron_covered(model_layer_dict3)[2]) + bcolors.ENDC)
        averaged_nc = (neuron_covered(model_layer_dict1)[0] + neuron_covered(model_layer_dict2)[0] +
                       neuron_covered(model_layer_dict3)[0]) / float(
            neuron_covered(model_layer_dict1)[1] + neuron_covered(model_layer_dict2)[1] +
            neuron_covered(model_layer_dict3)[
                1])
        print(bcolors.OKGREEN + '     averaged covered neurons %.3f' % (averaged_nc) + bcolors.ENDC)

        gen_img_deprocessed = deprocess_image(gen_img)

        # save the result to disk
        outputfilepath0 = os.path.join(output_dir, 'already_differ_' + str(label1) + '_' + str(label2) + '_' + str(label3) +'_['+ str(_) +  '].png')
        imageio.imwrite(outputfilepath0, gen_img_deprocessed)
        continue

    # if all label agrees
    orig_label = label1
    layer_name1, index1 = neuron_to_cover(model_layer_dict1)
    layer_name2, index2 = neuron_to_cover(model_layer_dict2)
    layer_name3, index3 = neuron_to_cover(model_layer_dict3)

    # construct joint loss function
    if args.target_model == 0:
        loss1 = -args.weight_diff * K.mean(model1.get_layer('before_softmax').output[..., orig_label])
        loss2 = K.mean(model2.get_layer('before_softmax').output[..., orig_label])
        loss3 = K.mean(model3.get_layer('before_softmax').output[..., orig_label])
    elif args.target_model == 1:
        loss1 = K.mean(model1.get_layer('before_softmax').output[..., orig_label])
        loss2 = -args.weight_diff * K.mean(model2.get_layer('before_softmax').output[..., orig_label])
        loss3 = K.mean(model3.get_layer('before_softmax').output[..., orig_label])
    elif args.target_model == 2:
        loss1 = K.mean(model1.get_layer('before_softmax').output[..., orig_label])
        loss2 = K.mean(model2.get_layer('before_softmax').output[..., orig_label])
        loss3 = -args.weight_diff * K.mean(model3.get_layer('before_softmax').output[..., orig_label])
    loss1_neuron = K.mean(model1.get_layer(layer_name1).output[..., index1])
    loss2_neuron = K.mean(model2.get_layer(layer_name2).output[..., index2])
    loss3_neuron = K.mean(model3.get_layer(layer_name3).output[..., index3])
    layer_output = (loss1 + loss2 + loss3) + args.weight_nc * (loss1_neuron + loss2_neuron + loss3_neuron)

    # for adversarial image generation
    final_loss = K.mean(layer_output)

    # we compute the gradient of the input picture wrt this loss
    grads = normalize(K.gradients(final_loss, input_tensor)[0])

    # this function returns the loss and grads given the input picture
    iterate = K.function([input_tensor], [loss1, loss2, loss3, loss1_neuron, loss2_neuron, loss3_neuron, grads])

    # we run gradient ascent for 20 steps
    for iters in range(args.grad_iterations):
        loss_value1, loss_value2, loss_value3, loss_neuron1, loss_neuron2, loss_neuron3, grads_value = iterate(
            [gen_img])
        if args.transformation == 'light':
            grads_value = constraint_light(grads_value)  # constraint the gradients value
        elif args.transformation == 'occl':
            grads_value = constraint_occl(grads_value, args.start_point,
                                          args.occlusion_size)  # constraint the gradients value
        elif args.transformation == 'blackout':
            grads_value = constraint_black(grads_value)  # constraint the gradients value

        gen_img += grads_value * args.step
        predictions1 = np.argmax(model1.predict(gen_img)[0])
        predictions2 = np.argmax(model2.predict(gen_img)[0])
        predictions3 = np.argmax(model3.predict(gen_img)[0])

        if not predictions1 == predictions2 == predictions3:
            update_coverage(gen_img, model1, model_layer_dict1, args.threshold)
            update_coverage(gen_img, model2, model_layer_dict2, args.threshold)
            update_coverage(gen_img, model3, model_layer_dict3, args.threshold)
            count_found += 1
            print(bcolors.OKBLUE + '%4d/%d. found at %d! covered neurons percentage %d neurons %.3f, %d neurons %.3f, %d neurons %.3f at %d/%d'
                  % (_, args.seeds, iters, len(model_layer_dict1), neuron_covered(model_layer_dict1)[2], len(model_layer_dict2),
                     neuron_covered(model_layer_dict2)[2], len(model_layer_dict3),
                     neuron_covered(model_layer_dict3)[2], count_found, count_already + count_found + count_not_found) + bcolors.ENDC)
            averaged_nc = (neuron_covered(model_layer_dict1)[0] + neuron_covered(model_layer_dict2)[0] +
                           neuron_covered(model_layer_dict3)[0]) / float(
                neuron_covered(model_layer_dict1)[1] + neuron_covered(model_layer_dict2)[1] +
                neuron_covered(model_layer_dict3)[
                    1])
            print(bcolors.OKBLUE + '     averaged covered neurons %.3f' % averaged_nc + bcolors.ENDC)

            gen_img_deprocessed = deprocess_image(gen_img)
            orig_img_deprocessed = deprocess_image(orig_img)

            # save the result to disk
            #outputfilepath = os.path.join(output_dir, args.transformation + '_' + str(label1) + '_' + str(label2) + '_' + str(label3) + '.png')
            outputfilepath = os.path.join(output_dir, args.transformation + '_from' + str(label1) + '_to' + str(predictions1) + '_'  + str(predictions2) + '_' + str(predictions3) +'_['+ str(_) +  '].png')
            #print(outputfilepath)
            imageio.imwrite(outputfilepath, gen_img_deprocessed)
#            outputfilepath2 = os.path.join(output_dir, args.transformation + '_' + str(label1) + '_' + str(label2) + '_' + str(label3) + '_orig.png')
            outputfilepath2 = os.path.join(output_dir, args.transformation + '_from' + str(label1) + '_to' + str(predictions1) + '_'  + str(predictions2) + '_' + str(predictions3) +'_['+ str(_) +  ']_orig.png')
            #print(outputfilepath2)
            imageio.imwrite(outputfilepath2, orig_img_deprocessed)
            break
        #add
        if iters == (args.grad_iterations-1):
            update_coverage(gen_img, model1, model_layer_dict1, args.threshold)
            update_coverage(gen_img, model2, model_layer_dict2, args.threshold)
            update_coverage(gen_img, model3, model_layer_dict3, args.threshold)
            averaged_nc = (neuron_covered(model_layer_dict1)[0] + neuron_covered(model_layer_dict2)[0] +
                           neuron_covered(model_layer_dict3)[0]) / float(
                neuron_covered(model_layer_dict1)[1] + neuron_covered(model_layer_dict2)[1] +
                neuron_covered(model_layer_dict3)[
                    1])
            count_not_found += 1
            print('%4d/%d. test suite was not found: averaged covered neurons %.3f at %d/%d' % (_, args.seeds, averaged_nc, count_not_found, count_already + count_found + count_not_found))

            gen_img_deprocessed = deprocess_image(gen_img)
            #orig_img_deprocessed = deprocess_image(orig_img)

            # save the result to disk
            #outputfilepath = os.path.join(output_dir, args.transformation + '_' + str(label1) + '_' + str(label2) + '_' + str(label3) + '.png')
            outputfilepath = os.path.join(output_dir, 'not_found_' + str(label1)+'_['+ str(_) + '].png')
#            print(outputfilepath)
            imageio.imwrite(outputfilepath, gen_img_deprocessed)
# Out:
#    0/400. found at 0! covered neurons percentage 52 neurons 0.577, 148 neurons 0.446, 268 neurons 0.399 at 1/1
#      averaged covered neurons 0.434
#    1/400. found at 1! covered neurons percentage 52 neurons 0.635, 148 neurons 0.541, 268 neurons 0.530 at 2/2
#      averaged covered neurons 0.545
#    2/400. found at 1! covered neurons percentage 52 neurons 0.712, 148 neurons 0.696, 268 neurons 0.724 at 3/3
#      averaged covered neurons 0.714
#    3/400. found at 2! covered neurons percentage 52 neurons 0.712, 148 neurons 0.709, 268 neurons 0.746 at 4/4
#      averaged covered neurons 0.731
#    4/400. found at 1! covered neurons percentage 52 neurons 0.712, 148 neurons 0.709, 268 neurons 0.757 at 5/5
#      averaged covered neurons 0.737
#    5/400. found at 1! covered neurons percentage 52 neurons 0.769, 148 neurons 0.750, 268 neurons 0.784 at 6/6
#      averaged covered neurons 0.771
#    6/400. found at 3! covered neurons percentage 52 neurons 0.788, 148 neurons 0.770, 268 neurons 0.795 at 7/7
#      averaged covered neurons 0.786
#    7/400. found at 1! covered neurons percentage 52 neurons 0.788, 148 neurons 0.797, 268 neurons 0.810 at 8/8
#      averaged covered neurons 0.803
#    8/400. found at 0! covered neurons percentage 52 neurons 0.788, 148 neurons 0.811, 268 neurons 0.821 at 9/9
#      averaged covered neurons 0.814
#    9/400. found at 2! covered neurons percentage 52 neurons 0.808, 148 neurons 0.811, 268 neurons 0.836 at 10/10
#      averaged covered neurons 0.825
#   10/400. test suite was not found: averaged covered neurons 0.833 at 1/11
#   11/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.831, 268 neurons 0.847 at 11/12
#      averaged covered neurons 0.840
#   12/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.838, 268 neurons 0.851 at 12/13
#      averaged covered neurons 0.844
#   13/400. found at 0! covered neurons percentage 52 neurons 0.827, 148 neurons 0.845, 268 neurons 0.866 at 13/14
#      averaged covered neurons 0.855
#   14/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.845, 268 neurons 0.866 at 14/15
#      averaged covered neurons 0.855
#   15/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.851, 268 neurons 0.866 at 15/16
#      averaged covered neurons 0.857
#   16/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.851, 268 neurons 0.866 at 16/17
#      averaged covered neurons 0.857
#   17/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.851, 268 neurons 0.866 at 17/18
#      averaged covered neurons 0.857
#   18/400. found at 4! covered neurons percentage 52 neurons 0.827, 148 neurons 0.851, 268 neurons 0.866 at 18/19
#      averaged covered neurons 0.857
#   19/400. found at 0! covered neurons percentage 52 neurons 0.827, 148 neurons 0.851, 268 neurons 0.877 at 19/20
#      averaged covered neurons 0.863
#   20/400. found at 2! covered neurons percentage 52 neurons 0.827, 148 neurons 0.851, 268 neurons 0.877 at 20/21
#      averaged covered neurons 0.863
#   21/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.851, 268 neurons 0.877 at 21/22
#      averaged covered neurons 0.863
#   22/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.851, 268 neurons 0.877 at 22/23
#      averaged covered neurons 0.863
#   23/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.858, 268 neurons 0.877 at 23/24
#      averaged covered neurons 0.865
#   24/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.858, 268 neurons 0.877 at 24/25
#      averaged covered neurons 0.865
#   25/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.858, 268 neurons 0.877 at 25/26
#      averaged covered neurons 0.865
#   26/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.865, 268 neurons 0.877 at 26/27
#      averaged covered neurons 0.868
#   27/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.872, 268 neurons 0.881 at 27/28
#      averaged covered neurons 0.872
#   28/400. found at 0! covered neurons percentage 52 neurons 0.827, 148 neurons 0.872, 268 neurons 0.881 at 28/29
#      averaged covered neurons 0.872
#   29/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.872, 268 neurons 0.881 at 29/30
#      averaged covered neurons 0.872
#   30/400. found at 1! covered neurons percentage 52 neurons 0.827, 148 neurons 0.872, 268 neurons 0.881 at 30/31
#      averaged covered neurons 0.872
#   31/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 31/32
#      averaged covered neurons 0.876
#   32/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 32/33
#      averaged covered neurons 0.876
#   33/400. found at 2! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 33/34
#      averaged covered neurons 0.876
#   34/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 34/35
#      averaged covered neurons 0.876
#   35/400. found at 2! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 35/36
#      averaged covered neurons 0.876
#   36/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 36/37
#      averaged covered neurons 0.876
#   37/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 37/38
#      averaged covered neurons 0.876
#   38/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 38/39
#      averaged covered neurons 0.876
#   39/400. found at 0! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 39/40
#      averaged covered neurons 0.876
#   40/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.884 at 40/41
#      averaged covered neurons 0.876
#   41/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.892 at 41/42
#      averaged covered neurons 0.880
#   42/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.892 at 42/43
#      averaged covered neurons 0.880
#   43/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.872, 268 neurons 0.896 at 43/44
#      averaged covered neurons 0.882
#   44/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.896 at 44/45
#      averaged covered neurons 0.885
#   45/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.896 at 45/46
#      averaged covered neurons 0.885
#   46/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.896 at 46/47
#      averaged covered neurons 0.885
#   47/400. found at 2! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.896 at 47/48
#      averaged covered neurons 0.885
#   48/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.896 at 48/49
#      averaged covered neurons 0.885
#   49/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.896 at 49/50
#      averaged covered neurons 0.885
#   50/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.896 at 50/51
#      averaged covered neurons 0.885
#   51/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.896 at 51/52
#      averaged covered neurons 0.885
#   52/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.899 at 52/53
#      averaged covered neurons 0.887
#   53/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.899 at 53/54
#      averaged covered neurons 0.887
#   54/400. found at 2! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.903 at 54/55
#      averaged covered neurons 0.889
#   55/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.903 at 55/56
#      averaged covered neurons 0.889
#   56/400. test suite was not found: averaged covered neurons 0.889 at 2/57
#   57/400. found at 2! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.903 at 56/58
#      averaged covered neurons 0.889
#   58/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.903 at 57/59
#      averaged covered neurons 0.889
#   59/400. found at 0! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.903 at 58/60
#      averaged covered neurons 0.889
#   60/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.903 at 59/61
#      averaged covered neurons 0.889
#   61/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.878, 268 neurons 0.903 at 60/62
#      averaged covered neurons 0.889
#   62/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 61/63
#      averaged covered neurons 0.891
#   63/400. found at 4! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 62/64
#      averaged covered neurons 0.891
#   64/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 63/65
#      averaged covered neurons 0.891
#   65/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 64/66
#      averaged covered neurons 0.891
#   66/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 65/67
#      averaged covered neurons 0.891
#   67/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 66/68
#      averaged covered neurons 0.891
#   68/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 67/69
#      averaged covered neurons 0.891
#   69/400. found at 1! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 68/70
#      averaged covered neurons 0.891
#   70/400. found at 3! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 69/71
#      averaged covered neurons 0.891
#   71/400. found at 3! covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.903 at 70/72
#      averaged covered neurons 0.891
# 72/400. input already causes different outputs (2,2,3) at1/73:
#      covered neurons percentage 52 neurons 0.846, 148 neurons 0.885, 268 neurons 0.910
#      averaged covered neurons 0.895
#   73/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.885, 268 neurons 0.914 at 71/74
#      averaged covered neurons 0.900
#   74/400. found at 4! covered neurons percentage 52 neurons 0.865, 148 neurons 0.885, 268 neurons 0.914 at 72/75
#      averaged covered neurons 0.900
#   75/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.885, 268 neurons 0.914 at 73/76
#      averaged covered neurons 0.900
#   76/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.885, 268 neurons 0.914 at 74/77
#      averaged covered neurons 0.900
#   77/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.885, 268 neurons 0.914 at 75/78
#      averaged covered neurons 0.900
#   78/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.885, 268 neurons 0.914 at 76/79
#      averaged covered neurons 0.900
#   79/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.914 at 77/80
#      averaged covered neurons 0.902
# 80/400. input already causes different outputs (4,2,4) at2/81:
#      covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918
#      averaged covered neurons 0.904
#   81/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 78/82
#      averaged covered neurons 0.904
#   82/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 79/83
#      averaged covered neurons 0.904
#   83/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 80/84
#      averaged covered neurons 0.904
#   84/400. found at 2! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 81/85
#      averaged covered neurons 0.904
#   85/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 82/86
#      averaged covered neurons 0.904
#   86/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 83/87
#      averaged covered neurons 0.904
#   87/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 84/88
#      averaged covered neurons 0.904
#   88/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 85/89
#      averaged covered neurons 0.904
#   89/400. found at 2! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 86/90
#      averaged covered neurons 0.904
#   90/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 87/91
#      averaged covered neurons 0.904
#   91/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 88/92
#      averaged covered neurons 0.904
#   92/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 89/93
#      averaged covered neurons 0.904
#   93/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 90/94
#      averaged covered neurons 0.904
#   94/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 91/95
#      averaged covered neurons 0.904
#   95/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 92/96
#      averaged covered neurons 0.904
#   96/400. found at 2! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 93/97
#      averaged covered neurons 0.904
#   97/400. found at 6! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 94/98
#      averaged covered neurons 0.904
#   98/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 95/99
#      averaged covered neurons 0.904
#   99/400. found at 4! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 96/100
#      averaged covered neurons 0.904
#  100/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 97/101
#      averaged covered neurons 0.904
#  101/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 98/102
#      averaged covered neurons 0.904
#  102/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 99/103
#      averaged covered neurons 0.904
#  103/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 100/104
#      averaged covered neurons 0.904
#  104/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 101/105
#      averaged covered neurons 0.904
#  105/400. found at 2! covered neurons percentage 52 neurons 0.865, 148 neurons 0.892, 268 neurons 0.918 at 102/106
#      averaged covered neurons 0.904
#  106/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 103/107
#      averaged covered neurons 0.906
#  107/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 104/108
#      averaged covered neurons 0.906
#  108/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 105/109
#      averaged covered neurons 0.906
#  109/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 106/110
#      averaged covered neurons 0.906
#  110/400. test suite was not found: averaged covered neurons 0.906 at 3/111
#  111/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 107/112
#      averaged covered neurons 0.906
#  112/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 108/113
#      averaged covered neurons 0.906
#  113/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 109/114
#      averaged covered neurons 0.906
#  114/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 110/115
#      averaged covered neurons 0.906
#  115/400. test suite was not found: averaged covered neurons 0.906 at 4/116
#  116/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 111/117
#      averaged covered neurons 0.906
#  117/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 112/118
#      averaged covered neurons 0.906
#  118/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 113/119
#      averaged covered neurons 0.906
#  119/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 114/120
#      averaged covered neurons 0.906
#  120/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 115/121
#      averaged covered neurons 0.906
#  121/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 116/122
#      averaged covered neurons 0.906
#  122/400. found at 7! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 117/123
#      averaged covered neurons 0.906
# 123/400. input already causes different outputs (5,5,4) at3/124:
#      covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918
#      averaged covered neurons 0.906
#  124/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 118/125
#      averaged covered neurons 0.906
#  125/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 119/126
#      averaged covered neurons 0.906
#  126/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 120/127
#      averaged covered neurons 0.906
#  127/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 121/128
#      averaged covered neurons 0.906
#  128/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 122/129
#      averaged covered neurons 0.906
#  129/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 123/130
#      averaged covered neurons 0.906
#  130/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 124/131
#      averaged covered neurons 0.906
#  131/400. found at 2! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 125/132
#      averaged covered neurons 0.906
#  132/400. found at 9! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 126/133
#      averaged covered neurons 0.906
#  133/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 127/134
#      averaged covered neurons 0.906
#  134/400. test suite was not found: averaged covered neurons 0.906 at 5/135
#  135/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 128/136
#      averaged covered neurons 0.906
#  136/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 129/137
#      averaged covered neurons 0.906
#  137/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 130/138
#      averaged covered neurons 0.906
#  138/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 131/139
#      averaged covered neurons 0.906
#  139/400. found at 2! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 132/140
#      averaged covered neurons 0.906
#  140/400. found at 7! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 133/141
#      averaged covered neurons 0.906
#  141/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 134/142
#      averaged covered neurons 0.906
#  142/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 135/143
#      averaged covered neurons 0.906
#  143/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 136/144
#      averaged covered neurons 0.906
#  144/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 137/145
#      averaged covered neurons 0.906
#  145/400. found at 6! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 138/146
#      averaged covered neurons 0.906
#  146/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 139/147
#      averaged covered neurons 0.906
#  147/400. found at 9! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 140/148
#      averaged covered neurons 0.906
#  148/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 141/149
#      averaged covered neurons 0.906
# 149/400. input already causes different outputs (9,9,4) at4/150:
#      covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918
#      averaged covered neurons 0.906
#  150/400. found at 5! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 142/151
#      averaged covered neurons 0.906
#  151/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 143/152
#      averaged covered neurons 0.906
#  152/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 144/153
#      averaged covered neurons 0.906
#  153/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 145/154
#      averaged covered neurons 0.906
#  154/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 146/155
#      averaged covered neurons 0.906
#  155/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 147/156
#      averaged covered neurons 0.906
#  156/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 148/157
#      averaged covered neurons 0.906
#  157/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 149/158
#      averaged covered neurons 0.906
#  158/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 150/159
#      averaged covered neurons 0.906
#  159/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 151/160
#      averaged covered neurons 0.906
#  160/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 152/161
#      averaged covered neurons 0.906
#  161/400. found at 2! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 153/162
#      averaged covered neurons 0.906
#  162/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 154/163
#      averaged covered neurons 0.906
#  163/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 155/164
#      averaged covered neurons 0.906
#  164/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 156/165
#      averaged covered neurons 0.906
#  165/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 157/166
#      averaged covered neurons 0.906
#  166/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 158/167
#      averaged covered neurons 0.906
#  167/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 159/168
#      averaged covered neurons 0.906
#  168/400. found at 2! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 160/169
#      averaged covered neurons 0.906
#  169/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 161/170
#      averaged covered neurons 0.906
#  170/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 162/171
#      averaged covered neurons 0.906
#  171/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 163/172
#      averaged covered neurons 0.906
#  172/400. found at 0! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 164/173
#      averaged covered neurons 0.906
#  173/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 165/174
#      averaged covered neurons 0.906
#  174/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 166/175
#      averaged covered neurons 0.906
#  175/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 167/176
#      averaged covered neurons 0.906
#  176/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 168/177
#      averaged covered neurons 0.906
#  177/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 169/178
#      averaged covered neurons 0.906
#  178/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 170/179
#      averaged covered neurons 0.906
#  179/400. found at 3! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 171/180
#      averaged covered neurons 0.906
#  180/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 172/181
#      averaged covered neurons 0.906
#  181/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.918 at 173/182
#      averaged covered neurons 0.906
#  182/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.922 at 174/183
#      averaged covered neurons 0.908
#  183/400. found at 1! covered neurons percentage 52 neurons 0.865, 148 neurons 0.899, 268 neurons 0.922 at 175/184
#      averaged covered neurons 0.908
# 184/400. input already causes different outputs (6,0,2) at5/185:
#      covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922
#      averaged covered neurons 0.910
#  185/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 176/186
#      averaged covered neurons 0.910
#  186/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 177/187
#      averaged covered neurons 0.910
#  187/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 178/188
#      averaged covered neurons 0.910
#  188/400. found at 2! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 179/189
#      averaged covered neurons 0.910
#  189/400. found at 9! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 180/190
#      averaged covered neurons 0.910
#  190/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 181/191
#      averaged covered neurons 0.910
#  191/400. found at 3! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 182/192
#      averaged covered neurons 0.910
#  192/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 183/193
#      averaged covered neurons 0.910
#  193/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 184/194
#      averaged covered neurons 0.910
#  194/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 185/195
#      averaged covered neurons 0.910
#  195/400. found at 3! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 186/196
#      averaged covered neurons 0.910
#  196/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 187/197
#      averaged covered neurons 0.910
#  197/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 188/198
#      averaged covered neurons 0.910
#  198/400. found at 3! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 189/199
#      averaged covered neurons 0.910
#  199/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 190/200
#      averaged covered neurons 0.910
#  200/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 191/201
#      averaged covered neurons 0.910
#  201/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 192/202
#      averaged covered neurons 0.910
#  202/400. found at 2! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 193/203
#      averaged covered neurons 0.910
#  203/400. found at 5! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 194/204
#      averaged covered neurons 0.910
#  204/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 195/205
#      averaged covered neurons 0.910
#  205/400. found at 6! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 196/206
#      averaged covered neurons 0.910
#  206/400. found at 2! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 197/207
#      averaged covered neurons 0.910
#  207/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 198/208
#      averaged covered neurons 0.910
#  208/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 199/209
#      averaged covered neurons 0.910
#  209/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 200/210
#      averaged covered neurons 0.910
#  210/400. test suite was not found: averaged covered neurons 0.910 at 6/211
#  211/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 201/212
#      averaged covered neurons 0.910
#  212/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 202/213
#      averaged covered neurons 0.910
#  213/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 203/214
#      averaged covered neurons 0.910
#  214/400. found at 5! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 204/215
#      averaged covered neurons 0.910
#  215/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 205/216
#      averaged covered neurons 0.910
#  216/400. found at 7! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 206/217
#      averaged covered neurons 0.910
#  217/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 207/218
#      averaged covered neurons 0.910
#  218/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 208/219
#      averaged covered neurons 0.910
#  219/400. found at 2! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 209/220
#      averaged covered neurons 0.910
#  220/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 210/221
#      averaged covered neurons 0.910
#  221/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 211/222
#      averaged covered neurons 0.910
#  222/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 212/223
#      averaged covered neurons 0.910
#  223/400. found at 4! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 213/224
#      averaged covered neurons 0.910
#  224/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 214/225
#      averaged covered neurons 0.910
#  225/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 215/226
#      averaged covered neurons 0.910
#  226/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 216/227
#      averaged covered neurons 0.910
#  227/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 217/228
#      averaged covered neurons 0.910
#  228/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.922 at 218/229
#      averaged covered neurons 0.910
#  229/400. test suite was not found: averaged covered neurons 0.910 at 7/230
#  230/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.925 at 219/231
#      averaged covered neurons 0.912
#  231/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.925 at 220/232
#      averaged covered neurons 0.912
#  232/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 221/233
#      averaged covered neurons 0.915
#  233/400. found at 2! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 222/234
#      averaged covered neurons 0.915
#  234/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 223/235
#      averaged covered neurons 0.915
#  235/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 224/236
#      averaged covered neurons 0.915
#  236/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 225/237
#      averaged covered neurons 0.915
#  237/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 226/238
#      averaged covered neurons 0.915
#  238/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 227/239
#      averaged covered neurons 0.915
#  239/400. found at 3! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 228/240
#      averaged covered neurons 0.915
#  240/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 229/241
#      averaged covered neurons 0.915
#  241/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.899, 268 neurons 0.929 at 230/242
#      averaged covered neurons 0.915
#  242/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 231/243
#      averaged covered neurons 0.917
#  243/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 232/244
#      averaged covered neurons 0.917
#  244/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 233/245
#      averaged covered neurons 0.917
#  245/400. found at 9! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 234/246
#      averaged covered neurons 0.917
# 246/400. input already causes different outputs (6,5,5) at6/247:
#      covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929
#      averaged covered neurons 0.917
#  247/400. found at 5! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 235/248
#      averaged covered neurons 0.917
#  248/400. test suite was not found: averaged covered neurons 0.917 at 8/249
#  249/400. found at 2! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 236/250
#      averaged covered neurons 0.917
#  250/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 237/251
#      averaged covered neurons 0.917
#  251/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 238/252
#      averaged covered neurons 0.917
#  252/400. test suite was not found: averaged covered neurons 0.917 at 9/253
#  253/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 239/254
#      averaged covered neurons 0.917
#  254/400. found at 7! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 240/255
#      averaged covered neurons 0.917
#  255/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 241/256
#      averaged covered neurons 0.917
#  256/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 242/257
#      averaged covered neurons 0.917
#  257/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 243/258
#      averaged covered neurons 0.917
#  258/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 244/259
#      averaged covered neurons 0.917
#  259/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 245/260
#      averaged covered neurons 0.917
#  260/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 246/261
#      averaged covered neurons 0.917
#  261/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 247/262
#      averaged covered neurons 0.917
#  262/400. found at 4! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 248/263
#      averaged covered neurons 0.917
#  263/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 249/264
#      averaged covered neurons 0.917
#  264/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 250/265
#      averaged covered neurons 0.917
#  265/400. found at 2! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 251/266
#      averaged covered neurons 0.917
#  266/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 252/267
#      averaged covered neurons 0.917
#  267/400. found at 3! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 253/268
#      averaged covered neurons 0.917
#  268/400. found at 2! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 254/269
#      averaged covered neurons 0.917
#  269/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 255/270
#      averaged covered neurons 0.917
#  270/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 256/271
#      averaged covered neurons 0.917
#  271/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 257/272
#      averaged covered neurons 0.917
#  272/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 258/273
#      averaged covered neurons 0.917
#  273/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 259/274
#      averaged covered neurons 0.917
# 274/400. input already causes different outputs (5,5,4) at7/275:
#      covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929
#      averaged covered neurons 0.917
#  275/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 260/276
#      averaged covered neurons 0.917
#  276/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 261/277
#      averaged covered neurons 0.917
#  277/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 262/278
#      averaged covered neurons 0.917
#  278/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 263/279
#      averaged covered neurons 0.917
#  279/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 264/280
#      averaged covered neurons 0.917
#  280/400. found at 3! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 265/281
#      averaged covered neurons 0.917
#  281/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 266/282
#      averaged covered neurons 0.917
#  282/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 267/283
#      averaged covered neurons 0.917
#  283/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 268/284
#      averaged covered neurons 0.917
#  284/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 269/285
#      averaged covered neurons 0.917
#  285/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 270/286
#      averaged covered neurons 0.917
#  286/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 271/287
#      averaged covered neurons 0.917
#  287/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 272/288
#      averaged covered neurons 0.917
#  288/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 273/289
#      averaged covered neurons 0.917
#  289/400. found at 3! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 274/290
#      averaged covered neurons 0.917
# 290/400. input already causes different outputs (3,8,3) at8/291:
#      covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929
#      averaged covered neurons 0.917
#  291/400. found at 8! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 275/292
#      averaged covered neurons 0.917
#  292/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 276/293
#      averaged covered neurons 0.917
#  293/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 277/294
#      averaged covered neurons 0.917
#  294/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 278/295
#      averaged covered neurons 0.917
# 295/400. input already causes different outputs (1,8,8) at9/296:
#      covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929
#      averaged covered neurons 0.917
#  296/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 279/297
#      averaged covered neurons 0.917
#  297/400. test suite was not found: averaged covered neurons 0.917 at 10/298
#  298/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 280/299
#      averaged covered neurons 0.917
#  299/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 281/300
#      averaged covered neurons 0.917
#  300/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 282/301
#      averaged covered neurons 0.917
#  301/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 283/302
#      averaged covered neurons 0.917
#  302/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 284/303
#      averaged covered neurons 0.917
#  303/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 285/304
#      averaged covered neurons 0.917
#  304/400. found at 2! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 286/305
#      averaged covered neurons 0.917
#  305/400. found at 3! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 287/306
#      averaged covered neurons 0.917
#  306/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 288/307
#      averaged covered neurons 0.917
#  307/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 289/308
#      averaged covered neurons 0.917
#  308/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 290/309
#      averaged covered neurons 0.917
#  309/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 291/310
#      averaged covered neurons 0.917
#  310/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 292/311
#      averaged covered neurons 0.917
#  311/400. found at 4! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 293/312
#      averaged covered neurons 0.917
#  312/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 294/313
#      averaged covered neurons 0.917
#  313/400. found at 5! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 295/314
#      averaged covered neurons 0.917
#  314/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 296/315
#      averaged covered neurons 0.917
#  315/400. found at 3! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 297/316
#      averaged covered neurons 0.917
#  316/400. found at 9! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.929 at 298/317
#      averaged covered neurons 0.917
#  317/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.933 at 299/318
#      averaged covered neurons 0.919
#  318/400. found at 0! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.933 at 300/319
#      averaged covered neurons 0.919
#  319/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.933 at 301/320
#      averaged covered neurons 0.919
#  320/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.933 at 302/321
#      averaged covered neurons 0.919
#  321/400. found at 1! covered neurons percentage 52 neurons 0.885, 148 neurons 0.905, 268 neurons 0.933 at 303/322
#      averaged covered neurons 0.919
#  322/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 304/323
#      averaged covered neurons 0.921
#  323/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 305/324
#      averaged covered neurons 0.921
#  324/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 306/325
#      averaged covered neurons 0.921
#  325/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 307/326
#      averaged covered neurons 0.921
# 326/400. input already causes different outputs (3,3,4) at10/327:
#      covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933
#      averaged covered neurons 0.921
#  327/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 308/328
#      averaged covered neurons 0.921
#  328/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 309/329
#      averaged covered neurons 0.921
# 329/400. input already causes different outputs (5,5,4) at11/330:
#      covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933
#      averaged covered neurons 0.921
#  330/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 310/331
#      averaged covered neurons 0.921
#  331/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 311/332
#      averaged covered neurons 0.921
#  332/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 312/333
#      averaged covered neurons 0.921
#  333/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 313/334
#      averaged covered neurons 0.921
#  334/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 314/335
#      averaged covered neurons 0.921
#  335/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 315/336
#      averaged covered neurons 0.921
#  336/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 316/337
#      averaged covered neurons 0.921
#  337/400. found at 5! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.933 at 317/338
#      averaged covered neurons 0.921
#  338/400. test suite was not found: averaged covered neurons 0.923 at 11/339
# 339/400. input already causes different outputs (5,5,3) at12/340:
#      covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937
#      averaged covered neurons 0.923
#  340/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 318/341
#      averaged covered neurons 0.923
#  341/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 319/342
#      averaged covered neurons 0.923
#  342/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 320/343
#      averaged covered neurons 0.923
# 343/400. input already causes different outputs (5,3,3) at13/344:
#      covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937
#      averaged covered neurons 0.923
#  344/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 321/345
#      averaged covered neurons 0.923
#  345/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 322/346
#      averaged covered neurons 0.923
#  346/400. found at 5! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 323/347
#      averaged covered neurons 0.923
#  347/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 324/348
#      averaged covered neurons 0.923
#  348/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 325/349
#      averaged covered neurons 0.923
#  349/400. test suite was not found: averaged covered neurons 0.923 at 12/350
#  350/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 326/351
#      averaged covered neurons 0.923
#  351/400. found at 5! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 327/352
#      averaged covered neurons 0.923
#  352/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 328/353
#      averaged covered neurons 0.923
#  353/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 329/354
#      averaged covered neurons 0.923
#  354/400. found at 2! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 330/355
#      averaged covered neurons 0.923
#  355/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 331/356
#      averaged covered neurons 0.923
#  356/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 332/357
#      averaged covered neurons 0.923
#  357/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 333/358
#      averaged covered neurons 0.923
#  358/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 334/359
#      averaged covered neurons 0.923
#  359/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 335/360
#      averaged covered neurons 0.923
#  360/400. found at 8! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 336/361
#      averaged covered neurons 0.923
#  361/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 337/362
#      averaged covered neurons 0.923
#  362/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 338/363
#      averaged covered neurons 0.923
#  363/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 339/364
#      averaged covered neurons 0.923
#  364/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 340/365
#      averaged covered neurons 0.923
#  365/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 341/366
#      averaged covered neurons 0.923
# 366/400. input already causes different outputs (9,4,4) at14/367:
#      covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937
#      averaged covered neurons 0.923
#  367/400. found at 3! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 342/368
#      averaged covered neurons 0.923
# 368/400. input already causes different outputs (9,7,7) at15/369:
#      covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937
#      averaged covered neurons 0.923
#  369/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 343/370
#      averaged covered neurons 0.923
#  370/400. found at 2! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 344/371
#      averaged covered neurons 0.923
#  371/400. found at 3! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 345/372
#      averaged covered neurons 0.923
#  372/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 346/373
#      averaged covered neurons 0.923
#  373/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 347/374
#      averaged covered neurons 0.923
#  374/400. found at 6! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 348/375
#      averaged covered neurons 0.923
#  375/400. found at 2! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 349/376
#      averaged covered neurons 0.923
#  376/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 350/377
#      averaged covered neurons 0.923
#  377/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 351/378
#      averaged covered neurons 0.923
#  378/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 352/379
#      averaged covered neurons 0.923
#  379/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 353/380
#      averaged covered neurons 0.923
#  380/400. found at 2! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 354/381
#      averaged covered neurons 0.923
#  381/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 355/382
#      averaged covered neurons 0.923
#  382/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 356/383
#      averaged covered neurons 0.923
#  383/400. found at 2! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 357/384
#      averaged covered neurons 0.923
#  384/400. found at 4! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 358/385
#      averaged covered neurons 0.923
#  385/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 359/386
#      averaged covered neurons 0.923
#  386/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 360/387
#      averaged covered neurons 0.923
#  387/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 361/388
#      averaged covered neurons 0.923
#  388/400. found at 4! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 362/389
#      averaged covered neurons 0.923
#  389/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 363/390
#      averaged covered neurons 0.923
#  390/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 364/391
#      averaged covered neurons 0.923
#  391/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 365/392
#      averaged covered neurons 0.923
#  392/400. found at 2! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 366/393
#      averaged covered neurons 0.923
#  393/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 367/394
#      averaged covered neurons 0.923
#  394/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 368/395
#      averaged covered neurons 0.923
#  395/400. found at 2! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 369/396
#      averaged covered neurons 0.923
#  396/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 370/397
#      averaged covered neurons 0.923
#  397/400. found at 6! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 371/398
#      averaged covered neurons 0.923
#  398/400. found at 1! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 372/399
#      averaged covered neurons 0.923
#  399/400. found at 0! covered neurons percentage 52 neurons 0.904, 148 neurons 0.905, 268 neurons 0.937 at 373/400
#      averaged covered neurons 0.923
# CPU times: user 1h 8min, sys: 22.9 s, total: 1h 8min 23s
# Wall time: 1h 8min 25s
